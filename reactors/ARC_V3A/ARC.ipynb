# %% [markdown]
# # Load and run ARC V3A

# %%
from fusdb import Reactor

# %%
ARC = Reactor.from_yaml("ARCV3A.yaml")

# %%
ARC.print_html_variables_table()
# Out:
# <table style='border-collapse:collapse;font-size:0.8em'><tr><th style='text-align:left;padding:2px 8px'>variable</th><th style='padding:2px 8px'>ARC V3A</th></tr><tr><td style='text-align:left;padding:2px 8px;font-weight:bold'>R</td><td style='padding:2px 8px;color:#6E6E6E'>4.62</td></tr><tr><td style='text-align:left;padding:2px 8px;font-weight:bold'>a</td><td style='padding:2px 8px;color:#6E6E6E'>1.18</td></tr><tr><td style='text-align:left;padding:2px 8px;font-weight:bold'>eps</td><td style='padding:2px 8px;color:#6E6E6E'>0.26</td></tr><tr><td style='text-align:left;padding:2px 8px;font-weight:bold'>kappa</td><td style='padding:2px 8px;color:#6E6E6E'>1.8</td></tr><tr><td style='text-align:left;padding:2px 8px;font-weight:bold'>delta</td><td style='padding:2px 8px;color:#6E6E6E'>0.65</td></tr><tr><td style='text-align:left;padding:2px 8px;font-weight:bold'>V_p</td><td style='padding:2px 8px;color:#6E6E6E'>189</td></tr><tr><td style='text-align:left;padding:2px 8px;font-weight:bold'
# ...

# %%
ARC.reconcile()
ARC.print_html_variables_table()
# Out:
# <table style='border-collapse:collapse;font-size:0.8em'><tr><th style='text-align:left;padding:2px 8px'>variable</th><th style='padding:2px 8px;color:#1EFF00'>ARC V3A</th></tr><tr><td style='text-align:left;padding:2px 8px;font-weight:bold'>R</td><td style='padding:2px 8px;color:#006100;background-color:#c6efce' title='Resistive flux
# Breakdown flux consumption
# Internal inductance (cylindrical)
# Toroidal field at outboard midplane
# Major radius
# Aspect ratio
# IPB elongation from volume
# Edge safety factor q_star
# Cylindrical edge safety factor
# Tokamak plasma surface
# Tokamak plasma volume'>4.62</td></tr><tr><td style='text-align:left;padding:2px 8px;font-weight:bold'>a</td><td style='padding:2px 8px;color:#006100;background-color:#c6efce' title='Poloidal field at outboard midplane
# Toroidal field at outboard midplane
# minor radius
# Aspect ratio
# IPB elongation from volume
# Cylindrical edge safety factor
# Tokamak plasma poloidal length
# ...
